# %%
import pandas as pd
import numpy as np
data = np.array(pd.read_csv('./data.csv'))
columns2 = np.array(['edible','cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
                   'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color', 'stalk-shape', 'stalk-root',
                   ' stalk-surface-above-ring', 'stalk-surface-below-ring', 'stalk-color-above-ring', 'stalk-color-below-ring',
                   'veil-type', 'veil-color', 'ring-number', 'ring-type', 'spore-print-color', 'population', 'habitat'])
abc = list('ABCDEFGHIJKLMNOPQRSTUVW')
df = pd.DataFrame(data, columns=columns2)
print( pd.unique(df.values.ravel()))
print(columns2)
print(df)
print(df.describe().transpose())
# Out:
# ['e' 'x' 's' 'y' 't' 'a' 'f' 'c' 'b' 'k' 'w' 'p' 'o' 'n' 'g' 'l' 'm' 'u'
#  'v' 'd' 'r' 'h' '?']
# ['edible' 'cap-shape' 'cap-surface' 'cap-color' 'bruises' 'odor'
#  'gill-attachment' 'gill-spacing' 'gill-size' 'gill-color' 'stalk-shape'
#  'stalk-root' ' stalk-surface-above-ring' 'stalk-surface-below-ring'
#  'stalk-color-above-ring' 'stalk-color-below-ring' 'veil-type'
#  'veil-color' 'ring-number' 'ring-type' 'spore-print-color' 'population'
#  'habitat']
#      edible cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0         e         x           s         y       t    a               f
# 1         e         b           s         w       t    l               f
# 2         p         x           y         w       t    p               f
# 3         e         x           s         g       f    n               f
# 4         e         x           y         y       t    a               f
# ...     ...       ...         ...       ...     ...  ...             ...
# ...

# %%
data = pd.get_dummies(df)
print(data)
# Out:
#       edible_e  edible_p  cap-shape_b  cap-shape_c  cap-shape_f  cap-shape_k  \
# 0            1         0            0            0            0            0
# 1            1         0            1            0            0            0
# 2            0         1            0            0            0            0
# 3            1         0            0            0            0            0
# 4            1         0            0            0            0            0
# ...        ...       ...          ...          ...          ...          ...
# 8118         1         0            0            0            0            1
# 8119         1         0            0            0            0            0
# 8120         1         0            0            0            1            0
# 8121         0         1            0            0            0            1
# 8122         1         0            0            0            0            0
#
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
vectorizer = TfidfVectorizer()
#vectorizer = CountVectorizer()
#vectors = vectorizer.fit_transform(data)
tfidf = TfidfVectorizer(preprocessor=lambda x: x, tokenizer=lambda x: x)
vectors = tfidf.fit_transform(nyData)

print(vectors.shape)
# Out:
# (119, 28)

# %%
df[['edible','habitat','population']].groupby(['habitat','edible']).count()
# Out:
#                 population
# habitat edible
# d       e             1880
#         p             1268
# g       e             1408
#         p              740
# l       e              240
#         p              592
# m       e              256
#         p               36
# p       e              136
#         p             1008
# u       e               96
#         p              271
# w       e              192

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sort: indices now can be used to sort by newsgroup below
indices = np.argsort(range(0,(len(data)-1)))

# Plot document-term matrix, blue indicates non-zero value
plt.spy(data.values[indices], markersize=0.1)
fig = plt.gcf()
fig.set_size_inches(60,400)
plt.plot(orientation='vertical')
plt.show()
